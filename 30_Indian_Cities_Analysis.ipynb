# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.offline import iplot
from plotly.subplots import make_subplots

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/ICT_Subdimension_Dataset.csv')

# %%
df.head(5)
# Out:
#      City  Year  Household Internet Access (%)  \
# 0  Mumbai  2019                          79.45
# 1  Mumbai  2020                          79.45
# 2  Mumbai  2021                          80.43
# 3  Mumbai  2022                          86.32
# 4  Mumbai  2023                          86.32
#
#    Fixed Broadband Subscriptions (%)  Wireless Broadband Subscriptions (%)  \
# 0                              48.00                                 50.35
# 1                              54.26                                 53.38
# 2                              54.26                                 60.42
# 3                              54.26                                 66.47
# 4                              54.26                                 66.47
#
#    Wireless Broadband Coverage 3G (%)  Wireless Broadband Coverage 4G (%)  \
# 0                               91.57                               59.19
# 1                               92.58                               64.12
# 2                               93.60                               69.06
# 3                               94.62                               73.99
# 4                               95.64                               78.92
#
#    Smart Water Meters (%)  Smart Electricity Meters (%)  \
# 0                   33.30                          43.4
# 1                   34.34                          43.4
# 2                   34.34                          43.4
# 3                   34.34                          43.4
# 4                   35.38                          43.4
#
#    Dynamic Public Transport Information (%)  Traffic Monitoring (%)  \
# 0                                     10.04                   15.30
# 1                                     14.06                   20.40
# 2                                     18.08                   25.49
# 3                                     22.09                   30.59
# 4                                     26.11                   35.69
#
#    Availability of WIFI in Public Areas (count)  \
# 0                                           137
# 1                                           172
# 2                                           167
# 3                                           142
# 4                                           143
#
#    Water Supply ICT Monitoring (%)  \
# 0                            31.31
# 1                            36.53
# 2                            41.74
# 3                            46.96
# 4                            52.18
#
#    Drainage / Storm Water System ICT Monitoring (%)  \
# 0                                             20.72
# 1                                             24.86
# 2                                             29.00
# 3                                             33.15
# 4                                             37.29
#
#    Electricity Supply ICT Monitoring (%)  Demand Response Penetration (%)  \
# 0                                  33.88                            10.05
# 1                                  38.72                            13.06
# 2                                  43.56                            16.08
# 3                                  48.40                            19.09
# 4                                  53.24                            22.11
#
#    Intersection Control (%)  Open data (%)  e-Government (%)  \
# 0                     15.48           4.85             19.07
# 1                     18.57           6.79             22.88
# 2                     21.67           8.73             26.70
# 3                     24.76          10.67             30.51
# 4                     27.86          12.61             34.32
#
#    Public Sector e-procurement (%)
# 0                            24.20
# 1                            29.04
# 2                            33.88
# 3                            38.73
# 4                            43.57

# %% [markdown]
# **Inspecting and Cleaning Dataframe Structure**

# %%
# Dataframe summary

def summary(df):
    print(f'data shape: {df.shape}')
    summ = pd.DataFrame(df.dtypes, columns=['Data Type'])
    summ['Missing#'] = df.isna().sum()
    summ['Missing%'] = (df.isna().sum())/len(df)
    summ['Dups'] = df.duplicated().sum()
    summ['Uniques'] = df.nunique().values
    summ['Count'] = df.count().values
    desc = pd.DataFrame(df.describe(include='all').transpose())
    summ['Min'] = desc['min'].values
    summ['Max'] = desc['max'].values
    summ['Average'] = desc['mean'].values
    summ['Standard Deviation'] = desc['std'].values
    summ['First Value'] = df.loc[0].values
    summ['Second Value'] = df.loc[1].values
    summ['Third Value'] = df.loc[2].values

    display(summ)

summary(df)
# Out:
# data shape: (180, 20)
#                                                  Data Type  Missing#  \
# City                                                object         0
# Year                                                 int64         0
# Household Internet Access (%)                      float64         0
# Fixed Broadband Subscriptions (%)                  float64         0
# Wireless Broadband Subscriptions (%)               float64         0
# Wireless Broadband Coverage 3G (%)                 float64         0
# Wireless Broadband Coverage 4G (%)                 float64         0
# Smart Water Meters (%)                             float64         0
# Smart Electricity Meters (%)                       float64         0
# Dynamic Public Transport Information (%)           float64         0
# Traffic Monitoring (%)                             float64         0
# Availability of WIFI in Public Areas (count)         int64         0
# Water Supply ICT Monitoring (%)                    float64         0
# Drainage / Storm Water System ICT Monitoring (%)   float64         0
# Electricity Supply ICT Monitoring (%)              float64         0
# Demand Response Penetration (%)                    float64         0
# Intersection Control (%)                           float64         0
# Open data (%)                                      float64         0
# e-Government (%)                                   float64         0
# Public Sector e-procurement (%)                    float64         0
#
#                                                   Missing%  Dups  Uniques  \
# City                                                   0.0     0       30
# Year                                                   0.0     0        6
# Household Internet Access (%)                          0.0     0      121
# Fixed Broadband Subscriptions (%)                      0.0     0      115
# Wireless Broadband Subscriptions (%)                   0.0     0      121
# Wireless Broadband Coverage 3G (%)                     0.0     0      167
# Wireless Broadband Coverage 4G (%)                     0.0     0      178
# Smart Water Meters (%)                                 0.0     0      111
# Smart Electricity Meters (%)                           0.0     0      102
# Dynamic Public Transport Information (%)               0.0     0      173
# Traffic Monitoring (%)                                 0.0     0      169
# Availability of WIFI in Public Areas (count)           0.0     0       65
# Water Supply ICT Monitoring (%)                        0.0     0      169
# Drainage / Storm Water System ICT Monitoring (%)       0.0     0      167
# Electricity Supply ICT Monitoring (%)                  0.0     0      170
# Demand Response Penetration (%)                        0.0     0      164
# Intersection Control (%)                               0.0     0      169
# Open data (%)                                          0.0     0      155
# e-Government (%)                                       0.0     0      165
# Public Sector e-procurement (%)                        0.0     0      175
#
#                                                   Count     Min     Max  \
# City                                                180     NaN     NaN
# Year                                                180  2019.0  2024.0
# Household Internet Access (%)                       180   53.65   92.63
# Fixed Broadband Subscriptions (%)                   180   23.97   60.72
# Wireless Broadband Subscriptions (%)                180    33.0   72.88
# Wireless Broadband Coverage 3G (%)                  180   85.57   99.56
# Wireless Broadband Coverage 4G (%)                  180   57.11   88.28
# Smart Water Meters (%)                              180    9.92   47.24
# Smart Electricity Meters (%)                        180   16.99   56.83
# Dynamic Public Transport Information (%)            180     9.5   31.46
# Traffic Monitoring (%)                              180   14.27   41.74
# Availability of WIFI in Public Areas (count)        180    67.0   172.0
# Water Supply ICT Monitoring (%)                     180   28.64    57.4
# Drainage / Storm Water System ICT Monitoring (%)    180   19.17   41.97
# Electricity Supply ICT Monitoring (%)               180   33.25   62.95
# Demand Response Penetration (%)                     180     9.6   26.23
# Intersection Control (%)                            180   14.32   31.41
# Open data (%)                                       180    4.75   15.68
# e-Government (%)                                    180   19.07   41.95
# Public Sector e-procurement (%)                     180   23.85   52.42
#
#                                                      Average  \
# City                                                     NaN
# Year                                                  2021.5
# Household Internet Access (%)                      72.998167
# Fixed Broadband Subscriptions (%)                  45.900444
# Wireless Broadband Subscriptions (%)               56.287444
# Wireless Broadband Coverage 3G (%)                 93.239944
# Wireless Broadband Coverage 4G (%)                 72.326944
# Smart Water Meters (%)                             29.933278
# Smart Electricity Meters (%)                       35.485389
# Dynamic Public Transport Information (%)           20.019389
# Traffic Monitoring (%)                             27.641611
# Availability of WIFI in Public Areas (count)      105.466667
# Water Supply ICT Monitoring (%)                    42.371889
# Drainage / Storm Water System ICT Monitoring (%)      30.104
# Electricity Supply ICT Monitoring (%)              47.803889
# Demand Response Penetration (%)                    17.553611
# Intersection Control (%)                           22.411278
# Open data (%)                                       9.936556
# e-Government (%)                                   30.018222
# Public Sector e-procurement (%)                    37.595278
#
#                                                  Standard Deviation  \
# City                                                            NaN
# Year                                                       1.712589
# Household Internet Access (%)                              8.984674
# Fixed Broadband Subscriptions (%)                          8.389596
# Wireless Broadband Subscriptions (%)                       8.716689
# Wireless Broadband Coverage 3G (%)                         3.124068
# Wireless Broadband Coverage 4G (%)                         8.791971
# Smart Water Meters (%)                                     7.813442
# Smart Electricity Meters (%)                                9.65294
# Dynamic Public Transport Information (%)                   6.886342
# Traffic Monitoring (%)                                     8.642577
# Availability of WIFI in Public Areas (count)              20.298168
# Water Supply ICT Monitoring (%)                            8.611707
# Drainage / Storm Water System ICT Monitoring (%)           6.938159
# Electricity Supply ICT Monitoring (%)                      8.724584
# Demand Response Penetration (%)                            5.177225
# Intersection Control (%)                                    5.16242
# Open data (%)                                              3.417569
# e-Government (%)                                           6.930577
# Public Sector e-procurement (%)                            8.653516
#
#                                                  First Value Second Value  \
# City                                                  Mumbai       Mumbai
# Year                                                    2019         2020
# Household Internet Access (%)                          79.45        79.45
# Fixed Broadband Subscriptions (%)                       48.0        54.26
# Wireless Broadband Subscriptions (%)                   50.35        53.38
# Wireless Broadband Coverage 3G (%)                     91.57        92.58
# Wireless Broadband Coverage 4G (%)                     59.19        64.12
# Smart Water Meters (%)                                  33.3        34.34
# Smart Electricity Meters (%)                            43.4         43.4
# Dynamic Public Transport Information (%)               10.04        14.06
# Traffic Monitoring (%)                                  15.3         20.4
# Availability of WIFI in Public Areas (count)             137          172
# Water Supply ICT Monitoring (%)                        31.31        36.53
# Drainage / Storm Water System ICT Monitoring (%)       20.72        24.86
# Electricity Supply ICT Monitoring (%)                  33.88        38.72
# Demand Response Penetration (%)                        10.05        13.06
# Intersection Control (%)                               15.48        18.57
# Open data (%)                                           4.85         6.79
# e-Government (%)                                       19.07        22.88
# Public Sector e-procurement (%)                         24.2        29.04
#
#                                                  Third Value
# City                                                  Mumbai
# Year                                                    2021
# Household Internet Access (%)                          80.43
# Fixed Broadband Subscriptions (%)                      54.26
# Wireless Broadband Subscriptions (%)                   60.42
# Wireless Broadband Coverage 3G (%)                      93.6
# Wireless Broadband Coverage 4G (%)                     69.06
# Smart Water Meters (%)                                 34.34
# Smart Electricity Meters (%)                            43.4
# Dynamic Public Transport Information (%)               18.08
# Traffic Monitoring (%)                                 25.49
# Availability of WIFI in Public Areas (count)             167
# Water Supply ICT Monitoring (%)                        41.74
# Drainage / Storm Water System ICT Monitoring (%)        29.0
# Electricity Supply ICT Monitoring (%)                  43.56
# Demand Response Penetration (%)                        16.08
# Intersection Control (%)                               21.67
# Open data (%)                                           8.73
# e-Government (%)                                        26.7
# Public Sector e-procurement (%)                        33.88

# %%
# Deleting unnecessary columns
df.drop(["Availability of WIFI in Public Areas (count)"], axis=1, inplace=True)

# %%
# Creating a column with the average of all features.
f = lambda x: sum(x[2:])
df['Mean'] = ((df.apply(f, axis = 1)) / 17).round(2)

# %% [markdown]
# **EDA**

# %%
# Cities by Average of all features and all years

fig, ax = plt.subplots(figsize=(8, 6))
df_city = df.groupby(['City'])[['Mean']].mean()
df_city.reset_index(level=0, inplace=True)
df_city = df_city.sort_values("Mean", axis = 0, ascending = False)
sns.barplot(data=df_city, y="City", x="Mean", palette = 'cool')
plt.title("Cities by Average of all features and all years", fontsize = 16)
plt.yticks(rotation=0, fontsize = 8)
plt.grid()
plt.show()

# %%
df_year = df.groupby(['Year', 'City'])[['Mean']].mean().reset_index()

df_year.head()
# Out:
#    Year       City   Mean
# 0  2019  Ahmedabad  30.99
# 1  2019     Aizawl  30.50
# 2  2019  Amaravati  32.25
# 3  2019   Amritsar  29.49
# 4  2019  Bengaluru  34.78

# %%
fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(data=df_year, x = 'Year', y = 'Mean', palette = 'Set1')
plt.title("Average of all cities per year", fontsize = 14)
plt.xticks(rotation=0, fontsize = 8)
plt.show()

# %%
# Top 5 Cities
options = ['Delhi', 'Kolkata', 'Bengaluru', 'Mumbai', 'Chennai']

# selecting rows based on condition
df_top = df.loc[df['City'].isin(options)]

fig, ax = plt.subplots(figsize=(10, 5))
sns.barplot(data=df_top, x="Year", y="Mean", hue="City", color = 'blue')
plt.title("To 5 Cities by Average of all features ", fontsize = 14)
plt.show()

# %%
cols = ['Household Internet Access (%)',
       'Fixed Broadband Subscriptions (%)',
       'Wireless Broadband Subscriptions (%)',
       'Wireless Broadband Coverage 3G (%)',
       'Wireless Broadband Coverage 4G (%)', 'Smart Water Meters (%)',
       'Smart Electricity Meters (%)',
       'Dynamic Public Transport Information (%)', 'Traffic Monitoring (%)',
       'Water Supply ICT Monitoring (%)',
       'Drainage / Storm Water System ICT Monitoring (%)',
       'Electricity Supply ICT Monitoring (%)',
       'Demand Response Penetration (%)', 'Intersection Control (%)',
       'Open data (%)', 'e-Government (%)', 'Public Sector e-procurement (%)']

colors = ["#8c0404","#f25ed0","#21618C","#16A085","#34495E",
          "#C70039", "#FF5733", "#FFC300", "#DAF7A6", "#B3B6B7",
          '#6495ED', '#40E0D0', '#9FE2BF', '#CCCCFF']

# %%
# Let's create a dataframe just for the year 2024
df_2024 = df[df['Year'] == 2024]
df_2024.head()
# Out:
#          City  Year  Household Internet Access (%)  \
# 5      Mumbai  2024                          86.32
# 11      Delhi  2024                          88.62
# 17  Bengaluru  2024                          92.63
# 23  Hyderabad  2024                          86.82
# 29    Chennai  2024                          87.74
#
#     Fixed Broadband Subscriptions (%)  Wireless Broadband Subscriptions (%)  \
# 5                               54.26                                 67.47
# 11                              56.62                                 65.61
# 17                              56.26                                 69.93
# 23                              60.00                                 56.54
# 29                              56.68                                 66.79
#
#     Wireless Broadband Coverage 3G (%)  Wireless Broadband Coverage 4G (%)  \
# 5                                96.65                               83.85
# 11                               93.93                               83.61
# 17                               99.55                               82.42
# 23                               94.07                               87.49
# 29                               97.99                               87.62
#
#     Smart Water Meters (%)  Smart Electricity Meters (%)  \
# 5                    35.38                         43.40
# 11                   38.33                         42.67
# 17                   37.96                         42.35
# 23                   35.18                         40.12
# 29                   40.45                         43.32
#
#     Dynamic Public Transport Information (%)  Traffic Monitoring (%)  \
# 5                                      30.13                   40.79
# 11                                     30.35                   41.18
# 17                                     28.78                   38.69
# 23                                     30.34                   38.05
# 29                                     31.42                   40.96
#
#     Water Supply ICT Monitoring (%)  \
# 5                             57.40
# 11                            52.50
# 17                            57.30
# 23                            56.56
# 29                            54.51
#
#     Drainage / Storm Water System ICT Monitoring (%)  \
# 5                                              41.43
# 11                                             41.32
# 17                                             39.29
# 23                                             38.80
# 29                                             38.56
#
#     Electricity Supply ICT Monitoring (%)  Demand Response Penetration (%)  \
# 5                                   58.08                            25.12
# 11                                  61.36                            24.14
# 17                                  62.95                            24.20
# 23                                  57.71                            24.73
# 29                                  58.96                            24.59
#
#     Intersection Control (%)  Open data (%)  e-Government (%)  \
# 5                      30.95          14.55             38.14
# 11                     31.27          14.60             38.61
# 17                     28.65          14.34             40.75
# 23                     28.99          14.26             41.93
# 29                     29.29          14.44             39.41
#
#     Public Sector e-procurement (%)   Mean
# 5                             48.41  50.14
# 11                            48.00  50.16
# 17                            47.95  50.82
# 23                            48.57  49.42
# 29                            47.78  50.62

# %%
# Cities with the highest "cols" - 2024

for i in cols:

    if i == 'Household Internet Access (%)':

        df_top = df_2024.groupby(['City'])[['Household Internet Access (%)']].mean()
        df_top = df_top.sort_values(by=("Household Internet Access (%)"), ascending=False).head(14)

        iplot(px.bar(df_top[:14],
             text_auto = True,
             color = df_top[:14].index,
             color_discrete_sequence = colors,
             labels=dict(index="Count Names",value=""),
             title = 'Cities with the highest Household Internet Access (%) - 2024'
            ))

    else:

        df_top = df_2024.groupby(['City'])[[i]].mean()
        df_top = df_top.sort_values(by=[i], ascending=False).head(14)

        iplot(px.bar(df_top[:14],
             text_auto = True,
             color = df_top[:14].index,
             color_discrete_sequence = colors,
             labels=dict(index="Count Names",value=""),
             title = 'Cities with the highest ' +i+ ' - 2024'
             ))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="22510656-e63d-4212-894e-1696c880bf13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22510656-e63d-4212-894e-1696c880bf13")) {                    Plotly.newPlot(                        "22510656-e63d-4212-894e-1696c880bf13",                        [{"alignmentgroup":"True","hovertemplate":"color=Bengaluru\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bengaluru","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru"],"xaxis":"x","y":[92.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Delhi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Delhi"],"xaxis":"x","y":[88.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chennai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Chennai","offsetgroup":"Chennai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chennai"],"xaxis":"x","y":[87.74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hyderabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hyderabad"],"xaxis":"x","y":[86.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mumbai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mumbai","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Mumbai"],"xaxis":"x","y":[86.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kolkata\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kolkata"],"xaxis":"x","y":[86.09],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nashik\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nashik","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Nashik","offsetgroup":"Nashik","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nashik"],"xaxis":"x","y":[83.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[83.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#DAF7A6","pattern":{"shape":""}} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1955d56c-2035-4b7c-83fa-8c6a44fd3e4b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1955d56c-2035-4b7c-83fa-8c6a44fd3e4b")) {                    Plotly.newPlot(                        "1955d56c-2035-4b7c-83fa-8c6a44fd3e4b",                        [{"alignmentgroup":"True","hovertemplate":"color=Kolkata\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kolkata"],"xaxis":"x","y":[60.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hyderabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hyderabad"],"xaxis":"x","y":[60.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[57.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ludhiana\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ludhiana","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Ludhiana","offsetgroup":"Ludhiana","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ludhiana"],"xaxis":"x","y":[56.78],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chennai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Chennai","offsetgroup":"Chennai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chennai"],"xaxis":"x","y":[56.68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Delhi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Delhi"],"xaxis":"x","y":[56.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bengaluru\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bengaluru","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru"],"xaxis":"x","y":[56.26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Surat\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Surat","offsetgroup":"Surat","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Surat"],"xaxis":"x","y":[56.09],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Talcher\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Talcher","marker":{"color":"#DAF7A6","pattern": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="70269487-4ee7-435e-a670-0b0a671f1d13" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70269487-4ee7-435e-a670-0b0a671f1d13")) {                    Plotly.newPlot(                        "70269487-4ee7-435e-a670-0b0a671f1d13",                        [{"alignmentgroup":"True","hovertemplate":"color=Thiruvananthapuram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thiruvananthapuram","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Thiruvananthapuram","offsetgroup":"Thiruvananthapuram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Thiruvananthapuram"],"xaxis":"x","y":[72.88],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Surat\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Surat","offsetgroup":"Surat","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Surat"],"xaxis":"x","y":[71.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[71.41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ludhiana\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ludhiana","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Ludhiana","offsetgroup":"Ludhiana","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ludhiana"],"xaxis":"x","y":[70.41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bengaluru\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bengaluru","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru"],"xaxis":"x","y":[69.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Talcher\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Talcher","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Talcher","offsetgroup":"Talcher","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Talcher"],"xaxis":"x","y":[69.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[69.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jorapokhar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jorapokhar","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Jorapokhar","offsetgroup":"Jorapokhar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jorapokhar"],"xaxis":"x","y":[68.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brajrajnagar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="875b82fe-34c2-4ff6-9838-5054400c8231" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("875b82fe-34c2-4ff6-9838-5054400c8231")) {                    Plotly.newPlot(                        "875b82fe-34c2-4ff6-9838-5054400c8231",                        [{"alignmentgroup":"True","hovertemplate":"color=Ernakulam\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ernakulam","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Ernakulam","offsetgroup":"Ernakulam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ernakulam"],"xaxis":"x","y":[99.56],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bengaluru\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bengaluru","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru"],"xaxis":"x","y":[99.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[98.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jorapokhar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jorapokhar","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Jorapokhar","offsetgroup":"Jorapokhar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jorapokhar"],"xaxis":"x","y":[98.69],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Surat\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Surat","offsetgroup":"Surat","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Surat"],"xaxis":"x","y":[98.67],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Visakhapatnam\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Visakhapatnam","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Visakhapatnam","offsetgroup":"Visakhapatnam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Visakhapatnam"],"xaxis":"x","y":[98.47],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Gurugram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gurugram","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Gurugram","offsetgroup":"Gurugram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Gurugram"],"xaxis":"x","y":[98.44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brajrajnagar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brajrajnagar","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Brajrajnagar","offsetgroup":"Brajrajnagar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Brajrajnagar"],"xaxis":"x","y":[98.43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amritsar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legen ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bfa05fe3-39ee-42a4-8b4c-7184430f7841" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfa05fe3-39ee-42a4-8b4c-7184430f7841")) {                    Plotly.newPlot(                        "bfa05fe3-39ee-42a4-8b4c-7184430f7841",                        [{"alignmentgroup":"True","hovertemplate":"color=Lucknow\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lucknow","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Lucknow","offsetgroup":"Lucknow","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Lucknow"],"xaxis":"x","y":[88.28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[88.16],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shillong\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shillong","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Shillong","offsetgroup":"Shillong","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Shillong"],"xaxis":"x","y":[87.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jaipur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jaipur","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Jaipur","offsetgroup":"Jaipur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jaipur"],"xaxis":"x","y":[87.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kolkata\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kolkata"],"xaxis":"x","y":[87.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chennai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Chennai","offsetgroup":"Chennai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chennai"],"xaxis":"x","y":[87.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hyderabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hyderabad"],"xaxis":"x","y":[87.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Aizawl\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aizawl","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Aizawl","offsetgroup":"Aizawl","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Aizawl"],"xaxis":"x","y":[87.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bhopal\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhopal","marker":{"color":"#DAF7A6","pattern":{"shap ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c1807638-21d8-4a72-bea1-f18fa2c38e66" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1807638-21d8-4a72-bea1-f18fa2c38e66")) {                    Plotly.newPlot(                        "c1807638-21d8-4a72-bea1-f18fa2c38e66",                        [{"alignmentgroup":"True","hovertemplate":"color=Thiruvananthapuram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thiruvananthapuram","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Thiruvananthapuram","offsetgroup":"Thiruvananthapuram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Thiruvananthapuram"],"xaxis":"x","y":[47.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[47.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nashik\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nashik","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Nashik","offsetgroup":"Nashik","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nashik"],"xaxis":"x","y":[47.09],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Gurugram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gurugram","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Gurugram","offsetgroup":"Gurugram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Gurugram"],"xaxis":"x","y":[46.72],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[46.31],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Surat\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Surat","offsetgroup":"Surat","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Surat"],"xaxis":"x","y":[45.82],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[45.76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Talcher\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Talcher","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Talcher","offsetgroup":"Talcher","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Talcher"],"xaxis":"x","y":[44.84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ludhiana\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ludhi ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d40d3b3a-0a55-4620-9bff-e4164ff6b98b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d40d3b3a-0a55-4620-9bff-e4164ff6b98b")) {                    Plotly.newPlot(                        "d40d3b3a-0a55-4620-9bff-e4164ff6b98b",                        [{"alignmentgroup":"True","hovertemplate":"color=Ludhiana\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ludhiana","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Ludhiana","offsetgroup":"Ludhiana","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ludhiana"],"xaxis":"x","y":[56.83],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[56.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Surat\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Surat","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Surat","offsetgroup":"Surat","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Surat"],"xaxis":"x","y":[55.76],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[55.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nashik\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nashik","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Nashik","offsetgroup":"Nashik","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nashik"],"xaxis":"x","y":[55.26],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ernakulam\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ernakulam","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Ernakulam","offsetgroup":"Ernakulam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ernakulam"],"xaxis":"x","y":[54.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Gurugram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Gurugram","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Gurugram","offsetgroup":"Gurugram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Gurugram"],"xaxis":"x","y":[54.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brajrajnagar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brajrajnagar","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Brajrajnagar","offsetgroup":"Brajrajnagar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Brajrajnagar"],"xaxis":"x","y":[54.63],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Talcher\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Talcher","marker":{"color":"#DAF7A6" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cd2e2894-3437-4de1-be88-57614747c5c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd2e2894-3437-4de1-be88-57614747c5c1")) {                    Plotly.newPlot(                        "cd2e2894-3437-4de1-be88-57614747c5c1",                        [{"alignmentgroup":"True","hovertemplate":"color=Patna\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patna","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Patna","offsetgroup":"Patna","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Patna"],"xaxis":"x","y":[31.46],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chennai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Chennai","offsetgroup":"Chennai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chennai"],"xaxis":"x","y":[31.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Thiruvananthapuram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thiruvananthapuram","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Thiruvananthapuram","offsetgroup":"Thiruvananthapuram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Thiruvananthapuram"],"xaxis":"x","y":[31.41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Talcher\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Talcher","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Talcher","offsetgroup":"Talcher","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Talcher"],"xaxis":"x","y":[31.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bhopal\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhopal","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Bhopal","offsetgroup":"Bhopal","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bhopal"],"xaxis":"x","y":[30.97],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kanpur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kanpur","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Kanpur","offsetgroup":"Kanpur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kanpur"],"xaxis":"x","y":[30.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Visakhapatnam\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Visakhapatnam","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Visakhapatnam","offsetgroup":"Visakhapatnam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Visakhapatnam"],"xaxis":"x","y":[30.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[30.65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Coimbatore\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e", ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3702a530-6c9e-45b4-b349-039ee0a8e9b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3702a530-6c9e-45b4-b349-039ee0a8e9b1")) {                    Plotly.newPlot(                        "3702a530-6c9e-45b4-b349-039ee0a8e9b1",                        [{"alignmentgroup":"True","hovertemplate":"color=Patna\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patna","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Patna","offsetgroup":"Patna","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Patna"],"xaxis":"x","y":[41.74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kanpur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kanpur","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Kanpur","offsetgroup":"Kanpur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kanpur"],"xaxis":"x","y":[41.68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[41.61],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Aizawl\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aizawl","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Aizawl","offsetgroup":"Aizawl","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Aizawl"],"xaxis":"x","y":[41.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kolkata\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kolkata"],"xaxis":"x","y":[41.52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jaipur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jaipur","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Jaipur","offsetgroup":"Jaipur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jaipur"],"xaxis":"x","y":[41.29],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Delhi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Delhi","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Delhi","offsetgroup":"Delhi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Delhi"],"xaxis":"x","y":[41.18],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bhopal\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhopal","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Bhopal","offsetgroup":"Bhopal","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bhopal"],"xaxis":"x","y":[40.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chennai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chennai","marker":{"color":"#DAF7A6","pattern":{"shape":""}},"name":"Chennai","offsetgroup" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35d0d982-ae9c-475a-ab49-ebcf8d9f1cc9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35d0d982-ae9c-475a-ab49-ebcf8d9f1cc9")) {                    Plotly.newPlot(                        "35d0d982-ae9c-475a-ab49-ebcf8d9f1cc9",                        [{"alignmentgroup":"True","hovertemplate":"color=Mumbai\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mumbai","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Mumbai","offsetgroup":"Mumbai","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Mumbai"],"xaxis":"x","y":[57.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Bengaluru\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bengaluru","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Bengaluru","offsetgroup":"Bengaluru","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bengaluru"],"xaxis":"x","y":[57.3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amritsar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amritsar","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Amritsar","offsetgroup":"Amritsar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amritsar"],"xaxis":"x","y":[57.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hyderabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hyderabad"],"xaxis":"x","y":[56.56],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Thiruvananthapuram\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Thiruvananthapuram","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Thiruvananthapuram","offsetgroup":"Thiruvananthapuram","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Thiruvananthapuram"],"xaxis":"x","y":[56.28],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[56.23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ludhiana\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ludhiana","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Ludhiana","offsetgroup":"Ludhiana","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ludhiana"],"xaxis":"x","y":[56.23],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jaipur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jaipur","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Jaipur","offsetgroup":"Jaipur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jaipur"],"xaxis":"x","y":[55.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Guwahati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9df2f976-ee30-42d6-a6d8-90541fd7988c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9df2f976-ee30-42d6-a6d8-90541fd7988c")) {                    Plotly.newPlot(                        "9df2f976-ee30-42d6-a6d8-90541fd7988c",                        [{"alignmentgroup":"True","hovertemplate":"color=Bhopal\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bhopal","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Bhopal","offsetgroup":"Bhopal","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Bhopal"],"xaxis":"x","y":[15.68],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[15.52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brajrajnagar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brajrajnagar","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Brajrajnagar","offsetgroup":"Brajrajnagar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Brajrajnagar"],"xaxis":"x","y":[15.52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shillong\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Shillong","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Shillong","offsetgroup":"Shillong","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Shillong"],"xaxis":"x","y":[15.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[15.44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nashik\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nashik","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Nashik","offsetgroup":"Nashik","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nashik"],"xaxis":"x","y":[15.41],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Patna\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Patna","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Patna","offsetgroup":"Patna","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Patna"],"xaxis":"x","y":[15.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Lucknow\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lucknow","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Lucknow","offsetgroup":"Lucknow","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Lucknow"],"xaxis":"x","y":[15.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kanpur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kanpur","marker":{"color":"#DAF7A6","pattern":{"shap ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="846fb3f7-f30c-42b9-b8f0-4b848490ed0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("846fb3f7-f30c-42b9-b8f0-4b848490ed0d")) {                    Plotly.newPlot(                        "846fb3f7-f30c-42b9-b8f0-4b848490ed0d",                        [{"alignmentgroup":"True","hovertemplate":"color=Aizawl\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aizawl","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Aizawl","offsetgroup":"Aizawl","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Aizawl"],"xaxis":"x","y":[41.95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Hyderabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hyderabad","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Hyderabad","offsetgroup":"Hyderabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hyderabad"],"xaxis":"x","y":[41.93],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Brajrajnagar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brajrajnagar","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Brajrajnagar","offsetgroup":"Brajrajnagar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Brajrajnagar"],"xaxis":"x","y":[41.9],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[41.75],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Guwahati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Guwahati","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Guwahati","offsetgroup":"Guwahati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Guwahati"],"xaxis":"x","y":[41.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Kolkata\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kolkata","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Kolkata","offsetgroup":"Kolkata","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kolkata"],"xaxis":"x","y":[41.52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Coimbatore\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Coimbatore","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Coimbatore","offsetgroup":"Coimbatore","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Coimbatore"],"xaxis":"x","y":[41.52],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jorapokhar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jorapokhar","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Jorapokhar","offsetgroup":"Jorapokhar","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jorapokhar"],"xaxis":"x","y":[41.43],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jaipur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jaipur","mark ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3a9198d2-9ad0-457a-b8ec-c531c0589434" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a9198d2-9ad0-457a-b8ec-c531c0589434")) {                    Plotly.newPlot(                        "3a9198d2-9ad0-457a-b8ec-c531c0589434",                        [{"alignmentgroup":"True","hovertemplate":"color=Kochi\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Kochi","marker":{"color":"#8c0404","pattern":{"shape":""}},"name":"Kochi","offsetgroup":"Kochi","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Kochi"],"xaxis":"x","y":[52.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nashik\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nashik","marker":{"color":"#f25ed0","pattern":{"shape":""}},"name":"Nashik","offsetgroup":"Nashik","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Nashik"],"xaxis":"x","y":[52.19],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Chandigarh\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Chandigarh","marker":{"color":"#21618C","pattern":{"shape":""}},"name":"Chandigarh","offsetgroup":"Chandigarh","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Chandigarh"],"xaxis":"x","y":[51.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amaravati\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amaravati","marker":{"color":"#16A085","pattern":{"shape":""}},"name":"Amaravati","offsetgroup":"Amaravati","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Amaravati"],"xaxis":"x","y":[51.69],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Aizawl\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aizawl","marker":{"color":"#34495E","pattern":{"shape":""}},"name":"Aizawl","offsetgroup":"Aizawl","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Aizawl"],"xaxis":"x","y":[51.62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jaipur\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Jaipur","marker":{"color":"#C70039","pattern":{"shape":""}},"name":"Jaipur","offsetgroup":"Jaipur","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Jaipur"],"xaxis":"x","y":[51.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ahmedabad\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ahmedabad","marker":{"color":"#FF5733","pattern":{"shape":""}},"name":"Ahmedabad","offsetgroup":"Ahmedabad","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Ahmedabad"],"xaxis":"x","y":[51.53],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Visakhapatnam\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Visakhapatnam","marker":{"color":"#FFC300","pattern":{"shape":""}},"name":"Visakhapatnam","offsetgroup":"Visakhapatnam","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Visakhapatnam"],"xaxis":"x","y":[51.37],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Amritsar\u003cbr\u003eCity=%{x}\u003cbr\u003e=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Amritsar","marker":{"color ...

# %%
fig, ax = plt.subplots(figsize=(12, 4))
sns.lineplot(data=df, x="City", y="Mean", hue="Year", palette = 'cool')
plt.title("City vs Mean by Year", fontsize = 18, color = 'blue')
plt.xticks(rotation=90, fontsize = 8)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# We can see throughout EDA and mainly from the graph above, that all 30 cities improved their information and technology services between the years 2019 and 2024. Furthermore, it is visible that the levels presented in 2019 increased almost equivalently year after year in all cities. Each line representing 1 year practically repeats its format in the following years. This allows us to conclude that the improvement in services is more of an action by the country as a whole than isolated actions in each city.
